# %% [markdown]
# # Carregamento dos Dados

# %%
import pandas as pd
from setuptools.command.rotate import rotate

CAMINHO = "C:\\Users\\Nitro\\Desktop\\Deep_Learning\\PETR4.SA2.csv"

df = pd.read_csv(CAMINHO)

df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2013-01-02  19.990000  20.209999  19.690001  19.690001  13.660646  30182600
# 1  2013-01-03  19.809999  20.400000  19.700001  20.400000  14.153233  30552600
# 2  2013-01-04  20.330000  20.620001  20.170000  20.430000  14.174045  36141000
# 3  2013-01-07  20.480000  20.670000  19.950001  20.080000  13.931217  28069600
# 4  2013-01-08  20.110001  20.230000  19.459999  19.500000  13.528824  29091300

# %% [markdown]
# # Tem linha do dataframe com dados faltando?

# %%
df[df.isna().any(axis=1)] # verifica qual linha é
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df = df.dropna()

len(df)
# Out:
# 2234

# %%
prices = df['Close']

# %% [markdown]
# # Visualização dos Dados

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,9))
plt.plot(df['Close'])
plt.xticks(range(0, df.shape[0], 200), df['Date'].loc[::200], rotation=45)
plt.xlabel("Datas", fontsize=18)
plt.ylabel("Preço Fechamento", fontsize = 18)
plt.title("Histórico de Preço PETR4", fontsize=30)
plt.show()

# %%
days_time_step = 15

# %% [markdown]
# # Separação teste e Treino

# %%
import numpy as np
training_size = int(len(prices) * 0.95)
test_size = len(prices) - training_size
train_data, input_data = np.array(prices[0: training_size]), np.array(prices[training_size- days_time_step:])
test_data = np.array(prices[training_size:])

train_data.shape, test_data.shape
# Out:
# ((2122,), (112,))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (18,9))
plt.plot(df['Close'].loc[0:train_data.shape[0]], color = 'blue', label = 'treino')
plt.plot(df['Close'].loc[train_data.shape[0]:], color = 'red', label = 'teste')
plt.xticks(range(0, df.shape[0], 100), df['Date'].loc[::100], rotation = 45)
plt.xlabel('Data', fontsize=18)
plt.ylabel('Preço Médio', fontsize=18)
plt.title('Histórico de Preço PETR4', fontsize=30)
plt.legend()
plt.show()

# %% [markdown]
# # Normalização dos Dados

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # Normaliza entre 0 e 1
train_data_norm = scaler.fit_transform(np.array(train_data).reshape(-1,1)) # (-1, 1) formato padrão para ML
test_data_norm = scaler.transform(np.array(input_data).reshape(-1, 1))
val_data_norm = scaler.transform(np.array(test_data).reshape(-1, 1))

train_data_norm
# Out:
# array([[0.57540863],
#        [0.60178304],
#        [0.60289745],
#        ...,
#        [0.83506683],
#        [0.81872211],
#        [0.83172359]], shape=(2122, 1))

# %% [markdown]
# # Pré-processamento (Gerando X e y)

# %%
#treino
X_train, y_train = [], []
for i in range(days_time_step, len(train_data)):
    X_train.append(train_data_norm[i-days_time_step:i])
    y_train.append(train_data_norm[i])

#teste
X_teste = []
for i in range(days_time_step, days_time_step + len(test_data)):
    X_teste.append(test_data_norm[i-days_time_step:i])

#val
X_val, y_val = [], []
for i in range(days_time_step, len(test_data)):
    X_val.append(val_data_norm[i-days_time_step:i])
    y_val.append(val_data_norm[i])

#converter tudo para matriz numpy
X_train = np.array(X_train)
y_train = np.array(y_train)
X_teste = np.array(X_teste)
X_val = np.array(X_val)
y_val = np.array(y_val)

X_teste.shape
# Out:
# (112, 15, 1)

# %% [markdown]
# # Trainamento de Rede Neural

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.21.0'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

model = Sequential()
model.add(SimpleRNN(100, return_sequences=False, input_shape=(days_time_step, 1)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
h = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0207 - val_loss: 0.0019
# Epoch 2/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 3/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 4/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 5/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 6/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3723e-04 - val_loss: 0.0016
# Epoch 7/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2991e-04 - val_loss: 0.0013
# Epoch 8/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5866e-04 - val_loss: 0.0011
# Epoch 9/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2358e-04 - val_loss: 0.0012
# Epoch 10/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4070e-04 - val_loss: 0.0010
# Epoch 11/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9775e-04 - val_loss: 0.0010
# Epoch 12/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3438e-04 - val_loss: 0.0011
# Epoch 13/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2948e-04 - val_loss: 0.0010
# Epoch 14/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0017e-04 - val_loss: 9.7245e-04
# Epoch 15/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3544e-04 - val_loss: 9.1433e-04
# Epoch 16/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0182e-04 - val_loss: 8.8447e-04
# Epoch 17/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5405e-04 - val_loss: 8.7969e-04
# Epoch 18/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6679e-04 - val_loss: 8.2982e-04
# Epoch 19/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9118e-04 - val_loss: 8.5095e-04
# Epoch 20/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2096e-04 - val_loss: 8.2837e-04
# Epoch 21/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.1549e-04 - val_loss: 7.9508e-04
# Epoch 22/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8773e-04 - val_loss: 8.3930e-04
# Epoch 23/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3835e-04 - val_loss: 8.9913e-04
# Epoch 24/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6325e-04 - val_loss: 8.0408e-04
# Epoch 25/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8792e-04 - val_loss: 9.1239e-04
# Epoch 26/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8403e-04 - val_loss: 7.7854e-04
# Epoch 27/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8167e-04 - val_loss: 7.8043e-04
# Epoch 28/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5253e-04 - val_loss: 7.7499e-04
# Epoch 29/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5876e-04 - val_loss: 6.8867e-04
# Epoch 30/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3150e-04 - val_loss: 7.0091e-04

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['loss'], label='loss')
plt.plot(h.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# # Avaliação de Resultados

# %%
#predição da valores pela rede
predict = model.predict(X_teste)

#transformação inversa do normalizador, para que possamos plotar no gráfico os resultados
predict = scaler.inverse_transform(predict)
real = test_data

predict.shape
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# (112, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 9))
plt.plot(real, color = 'green', label = 'real')
plt.plot(predict, color = 'red', label = 'previsão')
plt.xticks(range(0, len(real), 50), df['Date'].iloc[- len(real)::50], rotation=45)
plt.xlabel("Datas", fontsize=18)
plt.ylabel("Preço Médio", fontsize=18)
plt.title("Projeção de Preço PETR4", fontsize=30)
plt.legend()
plt.show()

# %%
import math
from sklearn.metrics import mean_squared_error
mean_squared_error(real, predict)
# Out:
# 0.5127701437178606

# %% [markdown]
# # Referências

# %% [markdown]
# https://www.datacamp.com/community/tutorials/lstm-python-stock-market
# https://www.analyticsvidhya.com/blog/2021/05/stock-price-prediction-and-forecasting-using-stacked-lstm/#:~:text=LSTMs%20are%20widely%20used%20for,the%20information%20that%20is%20not.
# https://www.analyticsvidhya.com/blog/2021/12/stock-price-prediction-using-lstm/
# https://medium.com/alexandre-george-lustosa/previs%C3%A3o-de-pre%C3%A7o-petr4-com-python-lstm-f93722be59e0
# https://finance.yahoo.com/quote/PETR4.SA/history?period1=1356998400&period2=1640995200&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true
# http://revistagt.fpl.edu.br/get/article/view/1930/1230
